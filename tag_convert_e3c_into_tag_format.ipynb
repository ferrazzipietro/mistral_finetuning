# %%
from datasets import load_dataset
from config.finetuning_llama2_tag import config
from utils.data_preprocessor import DataPreprocessorTag
from dotenv import dotenv_values

HF_TOKEN_WRITE = dotenv_values(".env.base")['HF_TOKEN_WRITE']

dataset = load_dataset(config.DATASET_CHEKPOINT) #download_mode="force_redownload"
dataset = dataset[config.TRAIN_LAYER]
dataset = dataset.shuffle(seed=1234)  # Shuffle dataset here
# Out:
# The kernel failed to start as the Python Environment '.venv (Python 3.6.9)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
preprocessor = DataPreprocessorTag("meta-llama/Llama-2-7b-chat-hf", "meta-llama/Llama-2-7b-chat-hf", token_llama=HF_TOKEN_WRITE, data =dataset, tagging_string='tag')
display(preprocessor.data)
preprocessor.apply(instruction_on_response_format='')
display(preprocessor.data[0])
# Out:
# MODEL TYPE: llama
# Dataset({
#     features: ['sentence', 'entities', 'original_text', 'original_id'],
#     num_rows: 1520
# })
# {'sentence': 'The results of the PCR were positive for RNA specific to SARS-CoV-2.', 'entities': [{'id': '9470', 'offsets': [19, 22], 'role': '', 'semantic_type_id': '', 'text': 'PCR', 'type': 'EVENT'}, {'id': '9485', 'offsets': [57, 67], 'role': '', 'semantic_type_id': '', 'text': 'SARS-CoV-2', 'type': 'EVENT'}, {'id': '10107', 'offsets': [57, 67], 'role': '', 'semantic_type_id': 'C5400365', 'text': 'SARS-CoV-2', 'type': 'CLINENTITY'}, {'id': '10347', 'offsets': [28, 36], 'role': '', 'semantic_type_id': '', 'text': 'positive', 'type': 'RML'}], 'original_text': 'A 43-year-old non-diabetic Indian male reported to our outpatient department with chief complaints of cough with expectoration, chest pain, reduced appetite, fever with chills, and night sweats for two weeks. He also complained of breathlessness on exertion and had two episodes of blood in his sputum. The patient explained that the cough was continuous and was relieved after taking cough syrup. He also mentioned that the episodes of fever were initially intermittent and then daily for the last two weeks and were relieved after taking Paracetamol. The chest pain was localized to the middle of the chest and was aggravated on exertion. He was a businessman by profession with no history of smoking, alcoholism, or any other substance abuse. Also, there was no history of any contact of TB or COVID-19 in the family or close contacts. And there was no history of foreign travel in the recent past. But he had reported having traveled by a domestic airline about twenty days back. There was no history of weight loss or any other major illness in the past.\r\nOn examination his vitals were-pulse-108/minute, arterial BP-130/80 mm of Hg, respiratory rate of 30 breaths/minute, Sp02-899% on room air, temperature- 101-degree centigrade. His Sp02 fell by 70% on room air after waking. On auscultation, there was crepitation on the bilateral middle lobes of the lungs. Also, dyspnea on exertion was noted. The rest of the systemic examination was within normal limits.\r\nConsidering this as a probable case of TB with COVID-19 he was advised a chest radiograph with sputum microscopy (Ziehl Neelsen (ZN) staining for acid-fast bacilli), Cartridge-based nucleic acid amplification test (CBNAAT) of the sputum and other routine investigations. To check for the COVID-19 he was advised qualitative polymerase chain reaction (PCR) test from the oropharyngeal swab. The results were surprising with Mycobacterium tuberculosis detected on sputum fluorescent microscopy and were also confirmed by the CBNAAT. However, there was no resistance to Rifampicin. The results of the PCR were positive for RNA specific to SARS-CoV-2. Besides, the chest radiograph PA-view was suggestive of bilateral consolidations on the middle lobes of lungs with ill-defined borders. The other investigations revealed a low lymphocyte count (1x 10 9 /L) and increased levels of C-reactive protein (CRP) (57 mg/L), lactate dehydrogenase (LDH) (580 U/L), and erythrocyte sedimentation rate (ESR) (70 mm in the 1 st hour). Also, a sample for liquid culture (MGIT BACTEC) was sent to the Intermediate Reference Laboratory (IRL) which revealed the growth of Mycobacterium tuberculosis. Computed tomography was not performed as the diagnosis was established by other cheaper and faster methods and also the patient was unwilling for the same. All the other routine investigations were within normal limits.\r\nHe was referred to the nearest designated COVID-19 management center, where he was managed as per national guidelines. Besides, he was also started on an antitubercular treatment of four drugs as per the National Tuberculosis Elimination Program (NTEP) guidelines. He was advised follow-up post completion of his stay at the designated COVID-19 center, but he has not yet reported back for follow-up. Written informed consent was obtained from the patient for using clinical data and images for publication in this study.\r\n', 'original_id': 'EN100606',  ...
# Map: 100%|██████████| 1520/1520 [00:00<00:00, 6926.78 examples/s]
# {'sentence': 'The results of the PCR were positive for RNA specific to SARS-CoV-2.',
#  'entities': [{'id': '9470',
#    'offsets': [19, 22],
#    'role': '',
#    'semantic_type_id': '',
#    'text': 'PCR',
#    'type': 'EVENT'},
#   {'id': '9485',
#    'offsets': [57, 67],
#    'role': '',
#    'semantic_type_id': '',
#    'text': 'SARS-CoV-2',
#    'type': 'EVENT'},
#   {'id': '10107',
#    'offsets': [57, 67],
#    'role': '',
#    'semantic_type_id': 'C5400365',
#    'text': 'SARS-CoV-2',
#    'type': 'CLINENTITY'},
#   {'id': '10347',
#    'offsets': [28, 36],
#    'role': '',
#    'semantic_type_id': '',
#    'text': 'positive',
#    'type': 'RML'}],
#  'original_text': 'A 43-year-old non-diabetic Indian male reported to our outpatient department with chief complaints of cough with expectoration, chest pain, reduced appetite, fever with chills, and night sweats for two weeks. He also complained of breathlessness on exertion and had two episodes of blood in his sputum. The patient explained that the cough was continuous and was relieved after taking cough syrup. He also mentioned that the episodes of fever were initially intermittent and then daily for the last two weeks and were relieved after taking Paracetamol. The chest pain was localized to the middle of the chest and was aggravated on exertion. He was a businessman by profession with no history of smoking, alcoholism, or any other substance abuse. Also, there was no history of any contact of TB or COVID-19 in the family or close contacts. And there was no history of foreign travel in the recent past. But he had reported having traveled by a domestic airline about twenty days back. There was no history of weight loss or any other major illness in the past.\r\nOn examination his vitals were-pulse-108/minute, arterial BP-130/80 mm of Hg, respiratory rate of 30 breaths/minute, Sp02-899% on room air, temperature- 101-degree centigrade. His Sp02 fell by 70% on room air after waking. On auscultation, there was crepitation on the bilateral middle lobes of the lungs. Also, dyspnea on exertion was noted. The rest of the systemic examination was within normal limits.\r\nConsidering this as a probable case of TB with COVID-19 he was advised a chest radiograph with sputum microscopy (Ziehl Neelsen (ZN) staining for acid-fast bacilli), Cartridge-based nucleic acid amplification test (CBNAAT) of the sputum and other routine investigations. To check for the COVID-19 he was advised qualitative polymerase chain reaction (PCR) test from the oropharyngeal swab. The results were surprising with Mycobacterium tuberculosis detected on sputum fluorescent microscopy and were also confirmed by the CBNAAT. However, there was no resistance to Rifampicin. The results of the PCR were positive for RNA specific to SARS-CoV-2. Besides, the chest radiograph PA-view was suggestive of bilateral consolidations on the middle lobes of lungs with ill-defined borders. The other investigations revealed a low lymphocyte count (1x 10 9 /L) and increased levels of C-reactive protein (CRP) (57 mg/L), lactate dehydrogenase (LDH) (580 U/L), and erythrocyte sedimentation rate (ESR) (70 mm in the 1 st hour). Also, a sample for liquid culture (MGIT BACTEC) was sent to the Intermediate Reference Laboratory (IRL) which revealed the growth of Mycobacterium tuberculosis. Computed tomography was not performed as the diagnosis was established by other cheaper and faster methods and also the patient was unwilling for the same. All the other routine investigations were within normal limits.\r\nHe was referred to the nearest designated COVID-19 management center, where he was managed as per national guidelines. Besides, he was also started on an antitubercular treatment of four drugs as per the National Tuberculosis Elimination Program (NTEP) guidelines. He was advised follow-up post completion of his stay at the designated COVID-19 center, but he has not yet reported back for follow-up. Written informed consent was obtained from the patient for using clinical data and images for publication in this study.\r\n',
#  'original_id': 'EN100606',
#  'sentence_tag': 'The results of the PCR were positive for RNA specific to <tag>SARS-CoV-2</tag>.',
#  'prompt': '<s>[INST]  <<The results of the PCR were positive for RNA specific to <tag>SARS-CoV-2</tag>.>>> [/INST][{"entity": "PCR"}, {"entity": "SARS-CoV-2"}, {"entity": "SARS-CoV-2"}, {"entity": "positive"}] </s>'}

# %%
def from_generativa_to_tag(example, entity_type_filter = False, entity_type='CLINENTITY'):
    to_add = len('<tag></tag>')
    base_sentence = example['sentence']
    entities = example['entities']
    entities = sorted(entities, key=lambda x: x['offsets'][0])
    sentence = ''
    prev_end=0

    # Initialize an empty list to store the filtered data, removing overlapping offsets
    filtered_entities = []
    current_end = -1
    for item in entities:
        start, end = item['offsets']
        if start > current_end:
            filtered_entities.append(item)
            current_end = end
    if entity_type_filter: filtered_entities = [ent for ent in filtered_entities if ent['type'] == entity_type]
    while len(filtered_entities) > 0:
        ent = filtered_entities.pop(0)
        start = ent['offsets'][0]
        end = ent['offsets'][1]
        sentence = sentence + base_sentence[prev_end:start] + '<tag>' + base_sentence[start:end] + '</tag>'
        prev_end = end
        if len(filtered_entities) == 0:
            sentence = sentence + base_sentence[end:]
            break
    if sentence=='':
        sentence = base_sentence
    example['prompt_tag'] = sentence
    return example

dataset = dataset.map(lambda x: from_generativa_to_tag(x, entity_type_filter=False))
# Out:
# Map: 100%|██████████| 1520/1520 [00:00<00:00, 9105.11 examples/s]
# ['The results of the <tag>PCR</tag> were <tag>positive</tag> for RNA specific to <tag>SARS-CoV-2</tag>.',
#  '<tag>Their child</tag> <tag>acquired</tag> <tag>walking</tag> at the age of 14 months.',
#  'An abdominal ultrasound <tag>examination</tag> was <tag>reported</tag> as <tag>normal</tag>.',
#  'Flow <tag>cytometry</tag> of <tag>the CSF</tag> <tag>showed</tag> that <tag>blast cells</tag> were <tag>positive</tag> for a cluster of differentiation <tag>markers</tag> (CD) (CD34, CD19, CD10, CD22 and <tag>partially positive</tag> for <tag>CD45</tag>) <tag>confirming</tag> <tag>CNS</tag> extramedullary lymphoid blast <tag>infiltration</tag>.',
#  'Her <tag>blood</tag> <tag>pressure</tag> was <tag>100/70 mmHg</tag> with a pulse <tag>rate</tag> of <tag>98 beats/min</tag>, respiratory <tag>rate</tag> about <tag>16/min</tag> and oral <tag>temperature</tag> of <tag>37°C</tag>.',
#  '<tag>She</tag> had also <tag>positive</tag> <tag>serum</tag> antibody against the Smith antigen and low serum <tag>level</tag> of C3 complement component: <tag>67 mg/dL</tag> (<tag>serum</tag> normal range: <tag>84</tag> – <tag>151</tag>).',
#  'Emergency <tag>neck</tag> computed tomography <tag>angiography</tag> <tag>showed</tag> a contrast-enhanced abscess <tag>cavity</tag> posterior to <tag>the left retropharyngeal space</tag>, and a low-density <tag>area</tag> <tag>surrounded</tag> by an area without contrast enhancement in <tag>the posterior neck</tag>.',
#  'The mitotic <tag>rate</tag> was extremely high (<tag>19 mitosis/10 high power field</tag>), and atypical mitotic <tag>figures</tag> were also present.',
#  "Within <tag>1 month</tag>, the <tag>boy's</tag> gastrointestinal <tag>symptoms</tag> were <tag>relieved</tag> and his <tag>behavior</tag> had <tag>changed</tag>.",
#  '<tag>Twenty five days later</tag>, <tag>she</tag> <tag>returned</tag> to obstetric emergencies for significant <tag>bleeding</tag> with <tag>severe anemia</tag> with <tag>hemoglobin</tag> <tag>9 g/dL</tag> without <tag>signs</tag> of <tag>hypovolemic shock</tag>.',
#  'Nasosinusal <tag>MRI</tag> <tag>shows</tag> a progressive <tag>increase</tag> in size of the <tag>tissue mass</tag> compared to the previously <tag>CT</tag> <tag>occupying</tag> <tag>the right nasal fossa</tag> on almost all of its height, <tag>measuring</tag> <tag>4 × 2.8 × 3.5cm</tag> without <tag>extension</tag> within <tag>the cavum</tag> with probable <tag>invasion</tag> of <tag>the lower part of the nasolacrimal duct</tag> and mass <tag>effect</tag> on both <tag>the sinusonasal bone septum</tag> and <tag>the intersinusonasal septum</tag>.',
#  '<tag>The patient</tag> was <tag>readmitted</tag> into our pediatric department with <tag>complains</tag> of <tag>severe headache</tag>, <tag>vomiting</tag>, <tag>pain</tag> and <tag>bilateral visual loss</tag> since <tag>three days</tag>.',
#  'Pertinent laboratory <tag>studies</tag> included a hemoglobin <tag>level</tag> of <tag>10 g/dL</tag>, platelet <tag>count</tag> was <tag>normal</tag>, blood <tag>urea</tag> of <tag>1,2 g</tag>/l (0,18-0,45 g/L), and a creatinine <tag>level</tag> of <tag>68 mg/L</tag> (7-13 mg/L).',
#  'Clinical <tag>examination</tag>, <tag>X-rays</tag>, and computed tomography <tag>scan</tag> <tag>revealed</tag> a <tag>posterior hip dislocation</tag> with an <tag>ipsilateral femoral head and mid-shaft fractures</tag>.',
#  'The <tag>electrocardiogram</tag> (<tag>EKG</tag>) <tag>showed</tag> <tag>grade III atrioventricular (AV) bloc</tag> with a ventricular <tag>rate</tag> of <tag>38 beats per minute</tag>.',
#  'There was no <tag>hemoperitoneum</tag>.',
#  'Fine needle aspiration <tag>cytology</tag> of the mass <tag>showed</tag> <tag>atypical ductal cells with nuclear pleomorphism</tag>, which were <tag>positive</tag> for <tag>ER</tag>, <tag>PR</tag> and <tag>Her2neu</tag> protein.',
#  'Initial <tag>assessment</tag> found Glasgow <tag>score</tag> (GCS) of <tag>12/15</tag> (eye <tag>opening</tag> at <tag>5</tag>, verbal <tag>response</tag> at <tag>2</tag>, motor <tag>response</tag> at <tag>5</tag>), symmetrical and reactive <tag>pupils</tag>, without feeling-motor <tag>deficit</tag>, normal osteotendinous <tag>reflexes</tag>, slightly <tag>polypneic</tag> at <tag>24 cycles/min</tag>, pulsed oxygen <tag>saturation</tag> (SpO 2) at <tag>97%</tag> in ambient air, <tag>he</tag> was <tag>tachycardic</tag> at <tag>115 bpm</tag> and <tag>hypertensive</tag> at <tag>160/95 mmHg</tag>, his capillary blood <tag>glucose</tag> at <tag>2.24 g/L</tag>, and glycosuria on the urine dipstick test without <tag>ketonuria</tag>.',
#  'Achieving a closed <tag>reduction</tag> is a <tag>challenge</tag> with ipsilateral fractures but it should be <tag>favored</tag> over open <tag>reduction</tag> due to a lower risk of <tag>complications</tag>.',
#  'Lab <tag>results</tag> <tag>showed</tag> <tag>haemoglobin</tag> <tag>10.9 g/dl</tag>, <tag>packed cell</tag> <tag>volume</tag> <tag>35%</tag>, and <tag>positive</tag> malaria <tag>parasites</tag>.',
#  '<tag>The patient</tag> underwent extended left <tag>parotidectomy</tag>.',
#  'Based on the Anatomical Pathology hysteroscopy <tag>result</tag>, <tag>treatment</tag> was done by using anti-tuberculosis drug category I (FDC 1X3 tab) <tag>for 6 months</tag>.',
#  'Residing in Middle East with background history of <tag>fever</tag>, <tag>backache</tag>, <tag>skin rash</tag>, <tag>splenomegaly</tag> and a low platelet count possibility of atypical infection like <tag>Brucellosis</tag> with NSAID induced <tag>gi bleed</tag> was considered.',
#  '<tag>A 12-year-old girl</tag> was referred to Department of Oral Surgery, with a <tag>complaint</tag> of <tag>pain</tag> and <tag>swelling</tag> in <tag>the left of maxilla</tag> that <tag>appeared</tag> <tag>3 months ago</tag>.',
#  'Thorough <tag>screening</tag> for other possible sources of <tag>infection</tag>, resulted <tag>negative</tag>.',
#  "Percutaneous <tag>drainage</tag> of both <tag>abscesses</tag>, combined with antimicrobial <tag>treatment</tag>, was <tag>successful</tag> and <tag>the patient's</tag> clinical <tag>condition</tag> <tag>improved</tag>.",
#  '<tag>Her mother</tag> had <tag>noticed</tag> a <tag>misalignment</tag> of <tag>the eyes</tag> <tag>three years previously</tag> and <tag>the patient</tag> had been <tag>complaining</tag> about <tag>poor distance vision</tag> for about <tag>a year</tag>.',
#  'An exploratory <tag>laparotomy</tag> has been <tag>indicated</tag> with presumptive diagnosis of <tag>intestinal duplication</tag>.',
#  'Then <tag>synovial tissue</tag> was <tag>excised</tag> with <tag>synoviectomy</tag>.',
#  '<tag>Microbiology</tag> <tag>revealed</tag> a Gram-negative <tag>bacterium</tag> that presented slow <tag>growth</tag>.',
#  '<tag>We</tag> <tag>present</tag> here a case of <tag>Macrophage activation syndrome</tag> associated with <tag>Griscelli syndrome type 2</tag> in <tag>a 3-years-old male</tag> born of consanguineous parentage.',
#  "The <tag>improvement</tag> of <tag>the patient's</tag> hemodynamic status resulted in an uneventful <tag>post-operative</tag> <tag>course</tag>.",
#  '<tag>The patient</tag> was sent <tag>home</tag> with <tag>prednisone</tag> and <tag>cyclosporine</tag>, <tag>He</tag> was <tag>placed</tag> on the list of bone marrow transplantation (BMT).',
#  'The total <tag>thyroidectomy</tag> was performed in two steps: initially a right <tag>lobo-isthmectomy</tag>, then the left <tag>lobectomy</tag>.',
#  'Contrast <tag>enema</tag> was <tag>unremarkable</tag>.',
#  '<tag>Nucleoli</tag> were generally inconspicuous.',
#  'The <tag>wound</tag> was <tag>explored</tag>; grommet and electrodes were <tag>removed</tag>.',
#  "The <tag>diagnosis</tag> of mixed cellularity type <tag>Castleman's disease</tag> was established and the <tag>patient</tag> <tag>recovered</tag> well.",
#  'The other <tag>investigations</tag> <tag>revealed</tag> a low lymphocyte <tag>count</tag> (<tag>1x 10 9 /L</tag>) and increased levels of C-reactive <tag>protein</tag> (<tag>CRP</tag>) (<tag>57 mg/L</tag>), lactate <tag>dehydrogenase</tag> (<tag>LDH</tag>) (<tag>580 U/L</tag>), and erythrocyte sedimentation <tag>rate</tag> (<tag>ESR</tag>) (<tag>70 mm</tag> in <tag>the 1 st hour</tag>).',
#  'Obstetric ultrasound <tag>measurements</tag> <tag>revealed</tag> a live <tag>pregnancy</tag> compatible with <tag>18 weeks</tag> <tag>gestation</tag> without any <tag>abnormality</tag>.',
#  '<tag>The patient</tag> was <tag>referred</tag> to a specialized dental <tag>surgeon</tag> and underwent periodontal <tag>therapy</tag> including surgical <tag>procedures</tag>.',
#  'Laboratory <tag>tests</tag> <tag>revealed</tag> that <tag>she</tag> had <tag>elevated</tag> bilirubin and liver enzyme <tag>levels</tag>.',
#  'An exploratory <tag>laparoscopy</tag> was performed, <tag>revealing</tag> a large amount of <tag>ascite</tag>, <tag>a normal liver</tag> <tag>appearance</tag>, and no <tag>granulations</tag> suggesting <tag>tuberculosis</tag> or peritoneal <tag>carcinosis</tag>.',
#  '<tag>A 20 years old man</tag> <tag>presented</tag> with <tag>fever</tag>, <tag>myalgias</tag>, <tag>arthralgias</tag>, <tag>retro-orbital pain</tag>, <tag>vomiting</tag> and <tag>gum bleeding</tag> during a large dengue <tag>outbreak</tag> in Lahore, Pakistan.',
#  '<tag>A 45 year old Indian female of Nordic origin</tag> <tag>presented</tag> <tag>5 years back</tag> with a <tag>lump</tag> in <tag>the right breast</tag> and <tag>the axilla</tag>.',
#  'This <tag>followed</tag> a course through <tag>the superficial inguinal ring</tag>, <tag>extended</tag> upwards to <tag>the anterior abdomninal wall</tag> below <tag>the subcutaneous plane</tag> and was <tag>fixed</tag> in the area of <tag>the right iliac crest</tag>.',
#  'Physical <tag>examination</tag> <tag>found</tag> an important <tag>swelling</tag> and obvious <tag>distortion</tag> at the <tag>dorsum of the hand</tag> associated with <tag>wounds of the ulnar and radial edges of the left hand</tag>.',
#  'Gadolinium enhanced <tag>brain</tag> <tag>MRI</tag> <tag>revealed</tag> multiple dilated pial venous vascular <tag>structures</tag> on <tag>right hemisphere</tag> also with the diffuse <tag>atrophy</tag> on the same side.',
#  '<tag>She</tag> had <tag>presented</tag> in <tag>July 2009</tag> with a history suggestive of <tag>IHD</tag> and <tag>angina</tag> class III (Canadian Cardiovascular society classification) which was <tag>worsening</tag> despite medical <tag>therapy</tag>.',
#  'The protocol has been <tag>interrupted</tag> <tag>4 years</tag> later because of a mild skin <tag>reaction</tag>.',
#  'The <tag>operation</tag> was <tag>finished</tag> by double aspiration drainage.',
#  'All the <tag>masses</tag> were <tag>excised</tag>.',
#  'The <tag>had</tag> and the <tag>wrist</tag> were <tag>immobilized</tag> with a splint for <tag>six weeks</tag>.',
#  '<tag>Bowel</tag> <tag>movements</tag> were <tag>normal</tag>.',
#  'On the other side there was no <tag>history</tag> of <tag>jaundice</tag>, <tag>vomiting</tag>, urinary or <tag>bowel complaints</tag>, <tag>bleeding</tag> from any site or neurological <tag>complaints</tag>.',
#  '<tag>She</tag> <tag>reported</tag> that during her pregnancy, <tag>she</tag> had exclusive <tag>feeding</tag> on the relief food provided by WFP (beans, yellow posho and cooking oil) during the IDP camps and <tag>denies</tag> history of <tag>ingestion</tag> of herbs or medications which caused adverse events during and after the pregnancy.',
#  'Forced duction <tag>test</tag> (performed under <tag>sedation</tag>) was <tag>positive</tag> and <tag>revealed</tag> marked <tag>restriction</tag> of passive elevation of <tag>the left eye</tag> in adduction.',
#  '<tag>Treatment</tag> of <tag>pulmonary embolism</tag> was <tag>initiated</tag> with subcutaneous low molecular weight <tag>heparin</tag> (enoxaparin 0.1 ml/10 kg/12h) followed by <tag>antivitamin</tag> K.',
#  'As <tag>discharge</tag> of <tag>serosanguinous fluid</tag> <tag>persisted</tag>, <tag>sacral wound</tag> was <tag>explored</tag>.',
#  '<tag>Orthopantomography</tag> and occlusal <tag>radiography</tag> <tag>showed</tag> a wide osteolytic <tag>area</tag> of <tag>the anterior left maxilla</tag>, <tag>extending</tag> from <tag>the first permanent molar</tag> to <tag>the central incisor</tag>.',
#  'His laboratory <tag>tests</tag> were all within <tag>normal range</tag>, including complete <tag>blood</tag> <tag>count</tag>, <tag>liver</tag> function <tag>tests</tag>, <tag>amylase</tag> and <tag>lipase</tag>.',
#  '<tag>A 61-year-old woman</tag>, gravida 3 para 3, <tag>presented</tag> with an increased size of <tag>ovarian cyst</tag>.',
#  'A thick, purulent material of 40cc was <tag>drained</tag> and <tag>sent</tag> for culture.',
#  '<tag>The elder sister</tag> had no <tag>feature</tag> of <tag>SWS</tag> and no <tag>researches</tag> were done regarding her <tag>stain</tag>.',
#  'Reverse transcription polymerase chain reaction of SARS-CoV-2 in CSF was <tag>positive</tag> but with a cycle threshold (CT) of 38.6.',
#  'There were no significant physical <tag>findings</tag>.',
#  'Transcranial Doppler <tag>examination</tag> was <tag>normal</tag>.',
#  '<tag>The patient</tag> remains <tag>asymptomatic</tag> and follow-up at <tag>24 months</tag> <tag>showed</tag> no evidence of recurrence or <tag>metastasis</tag>.',
#  'The <tag>defect</tag> was then <tag>packed</tag> cancellous <tag>bone</tag> graft.',
#  'The CD10 <tag>immunostain</tag> was <tag>positive</tag>.',
#  'On <tag>7th day</tag> of <tag>illness</tag> <tag>patient</tag> became <tag>afebrile</tag>, but <tag>he</tag> developed severe <tag>headaches</tag>, <tag>unconsciousness</tag> followed by <tag>altered behavior</tag>.',
#  'Pelvic <tag>examination</tag> was <tag>normal</tag>.',
#  'Immunological workup <tag>revealed</tag> antinuclear antibodies <tag>titer</tag> of <tag>1:1280</tag>, <tag>positive</tag> <tag>anti-SSA</tag> and anti-SM <tag>antibodies</tag> and <tag>hypocomplementemia</tag>.',
#  '<tag>Follow</tag> up on <tag>the pregnant patient</tag> was <tag>uneventful</tag> <tag>a month later</tag>.',
#  'In the absence of arterial <tag>embolization</tag>, <tag>she</tag> was going with ambulatory <tag>monitoring</tag>.',
#  'The diagnostic <tag>test</tag> such as <tag>Ca-125</tag>, <tag>AFP</tag>, <tag>free-T4</tag> and <tag>TSH</tag> was in <tag>normal range</tag>.',
#  '<tag>She</tag> was performed a proteus intelligence <tag>test</tag> in which <tag>she</tag> had <tag>75 points</tag> and accepted as <tag>mildly mentally retarded</tag>.',
#  '<tag>She</tag> has been adequately <tag>treated</tag> for <tag>acute pelvic inflammatory disease</tag> <tag>five years earlier</tag>.',
#  'The <tag>patient</tag> was <tag>started</tag> on intravenous <tag>therapy</tag> with methylprednisolone followed by prednisone 60mg by mouth <tag>daily</tag> with hydroxychloroquine.',
#  '<tag>Patient</tag> had <tag>elevated</tag> <tag>WBC</tag> “<tag>12.52 x 10 9 /L</tag>” and <tag>Platelet</tag> “<tag>453 x 10 9 /L</tag>” with reduction in <tag>RBC</tag> “<tag>4.4 x 10 9 /L</tag>” and Eosinophil <tag>count</tag> “<tag>0.07</tag>”.',
#  'There is sometimes a somewhat palisadic <tag>seat</tag> on the periphery of the <tag>tumor mass</tag>.',
#  'On her ophthalmological <tag>evaluation</tag> <tag>she</tag> was <tag>diagnosed</tag> with <tag>glaucoma</tag> of <tag>the right eye</tag>.',
#  '<tag>The patient</tag> was <tag>transferred</tag> to the recovery room with complete <tag>stability</tag>.',
#  "A CT <tag>scan</tag> <tag>revealed</tag> small bilateral pleural <tag>effusions</tag>, small hepatic <tag>enlargement</tag>, <tag>Gerota's fascia</tag> <tag>thickening</tag>, <tag>perineal soft tissue</tag> <tag>stranding</tag> with fascial thickening and small bubbles of air.",
#  '<tag>The pancreas</tag> was <tag>explored</tag> through <tag>the gastrocolic omentum</tag>.',
#  'It took heterogeneously the contrast and then evocate a large <tag>MNG</tag>.',
#  'In <tag>April 2015</tag> the dose of mycophenolate was <tag>decreased</tag> but <tag>anticoagulation</tag> was <tag>continued</tag> until the beginning of <tag>July 2015</tag> to <tag>ensure</tag> that <tag>decreasing</tag> immune <tag>suppression</tag> did not <tag>allow</tag> the emergence of another <tag>flare</tag> with attendant thrombotic risk.',
#  'Transthoracic <tag>echocardiography</tag> <tag>revealed</tag> an anomalous accelerated <tag>flow</tag>, indicating an anomalous systemic pulmonary <tag>shunt</tag>.',
#  '<tag>We</tag> <tag>removed</tag> the large <tag>sac</tag> after <tag>separating</tag> <tag>the vas</tag> and <tag>vessels</tag> and <tag>the testis</tag>.',
#  'Following surgery, <tag>the patient</tag> underwent four cycles of doxorubicin and cyclophosphamide and twelve cycles of paclitaxel chemotherapy.',
#  'A palpable <tag>mass</tag> along <tag>the anterior margin of the sternocleidomastoid muscle</tag> was also <tag>noticed</tag>.',
#  'The refractive <tag>error</tag> was a <tag>hypermetropia</tag> of <tag>+4.50 diopters</tag> in <tag>each eye</tag>.',
#  'Due to the extent of the surgical <tag>debridement</tag>, <tag>the patient</tag> was <tag>admitted</tag> <tag>postoperatively</tag> to the ICU (<tag>SOFA</tag> score <tag>6</tag>, <tag>APACHE</tag> II score <tag>12</tag>); where <tag>sedation</tag> (<tag>midazolam</tag> 30 mcg/kg/hr c.iv), <tag>analgesia</tag> (<tag>fentanyl</tag> 3 mcg/kg/min c.iv), triple antibiotic <tag>regimen</tag> with meropenem 2gr <tag>q8h</tag> i.v., clindamycin 600mg <tag>q 6h</tag> i.v. and daptomycin 500mg <tag>q.d.</tag> i.v., gastroprotective and antithrombotic <tag>prophylaxis</tag> were <tag>initiated</tag>.',
#  '<tag>A 62-year-old woman</tag> <tag>presented</tag> with <tag>complaints</tag> of <tag>epigastric pain</tag> and <tag>vomiting</tag>.',
#  'The <tag>wound</tag> was <tag>closed</tag> with interrupted sutures.',
#  'Clinical <tag>signs</tag> on examination included mild <tag>pallor</tag> and <tag>cholestatic jaundice</tag>.',
#  '<tag>His parents</tag> had <tag>noted</tag> an <tag>ankle trauma</tag> in <tag>the previous week</tag>.',
#  'Anteroposterior and lateral <tag>radiographs</tag> of <tag>the cervical spine</tag> <tag>show</tag> <tag>an elongated left spinous process</tag> in <tag>the neck</tag> at the level of <tag>C5 vertebrae</tag>.',
#  '<tag>Urine</tag> <tag>analysis</tag> <tag>showed</tag> trace <tag>protein</tag> (<tag>0.03g/24h</tag>).',
#  "During the <tag>treatment</tag>, the <tag>patient's</tag> appetite was <tag>unstable</tag>.",
#  'Coronary <tag>angiography</tag> done <tag>demonstrated</tag> significant <tag>lesions</tag> in the mid portion of <tag>the Left Descending Coronary Artery</tag> (<tag>LAD</tag>) and <tag>the proximal Circumflex Coronary Artery</tag> (<tag>Cx</tag>).',
#  '<tag>Knee</tag> <tag>MRI</tag> <tag>revealed</tag> many loose <tag>bodies</tag> (consistent with <tag>synovial chondromatosis</tag>) isointense with <tag>fatty bone marrow</tag> at all sequences at the level of <tag>right knee joint</tag>.',
#  'After <tag>18 hours</tag> the <tag>labour</tag> seemed to <tag>proceed</tag> well with cervical <tag>dilatation</tag> of 6 cm, <tag>level</tag> of <tag>head</tag> <tag>0</tag>, but the cardiotocography (CTG) <tag>trace</tag> <tag>revealed</tag> <tag>anomalies</tag> that after <tag>1 hour</tag> <tag>induced</tag> the <tag>shift</tag> versus cesarean <tag>section</tag>.',
#  "The output's <tag>weight</tag> was <tag>2400g</tag> which signify the <tag>loss</tag> of 630g.",
#  "<tag>She</tag> was <tag>evaluated</tag> by urology and a right partial <tag>nephrectomy</tag> was <tag>planned</tag>, however on <tag>the day</tag> of the <tag>procedure</tag>, the <tag>patient's</tag> <tag>preoperative</tag> pregnancy <tag>test</tag> was <tag>positive</tag>.",
#  '<tag>He</tag> <tag>denied</tag> having any prior episodes of <tag>acute pancreatitis</tag> and had no history of alcohol <tag>use</tag>.',
#  '<tag>He</tag> <tag>received</tag> supplementary food <tag>rehabilitation</tag> and his seizure medication was changed to Sodium Valproate 200mg once a day under direct observation therapy (DOTS) and close monitoring of the vital signs.',
#  'Brucella agglutination <tag>test</tag> was negative.',
#  'However, time to <tag>progression</tag> after <tag>start</tag> of sorafenib <tag>administration</tag> did not exceed <tag>6\xa0months</tag> and the <tag>regimen</tag> was <tag>changed</tag> to <tag>monotherapy</tag> with Pazopanib, another TKI predicted to be <tag>effective</tag> for <tag>this patient</tag> according to the same molecular <tag>test</tag>.',
#  '<tag>The abdomen</tag> appeared neither <tag>tender</tag> nor <tag>distended</tag>, and the rest of his physical <tag>examination</tag> was <tag>normal</tag>.',
#  'Considering the severe sudden <tag>pain</tag> <tag>complaint</tag> and <tag>adnexal mass</tag> <tag>finding</tag>, explorative <tag>laparotomy</tag> was <tag>planned</tag> for the suspected diagnosis of <tag>adnexal torsion</tag>.',
#  'The <tag>24 hours</tag> ECG <tag>monitoring</tag> <tag>showed</tag> a sinus <tag>rhythm</tag>.',
#  "<tag>He</tag> <tag>lost</tag> 930g relative to the birth's <tag>weight</tag>.",
#  'The <tag>lesion</tag> was <tag>located</tag> in <tag>the femoral region of the right lower extremity</tag> and surgically <tag>resected</tag> after radiographic <tag>workup</tag> and excisional biopsy <tag>examinations</tag>.',
#  'A <tag>chest</tag> <tag>X-ray</tag> <tag>showed</tag> an appropriate cardiac <tag>size</tag>.',
#  '<tag>Urine</tag> <tag>analysis</tag> and <tag>culture</tag> were performed <tag>several times</tag> that was <tag>negative</tag> for <tag>infection</tag>.',
#  '<tag>Gastric mucosa</tag> was strictly normal in direct vision and in retrovision, the <tag>bulb</tag> and <tag>duodenum</tag> were normal.',
#  '<tag>Arterial gas</tag> <tag>testing</tag> <tag>showed</tag> normal corrected anion gap metabolic <tag>acidosis</tag>, with <tag>hypokalaemia</tag> at <tag>3 mmol/L</tag> and normal <tag>lactatemia</tag> at <tag>0.43 mmol/L</tag>.',
#  '<tag>Antero-posterior and lateral knee</tag> <tag>X-rays</tag> <tag>showed</tag> degenerative <tag>changes</tag> and a giant, irregular, calcific <tag>mass</tag> which <tag>started</tag> below <tag>patella</tag> and <tag>extended</tag> to <tag>suprapatellar area</tag>.',
#  'Complete <tag>blood</tag> <tag>count</tag> <tag>revealed</tag> marked neutrophilic <tag>leukocytosis</tag> (<tag>WBC</tag> <tag>23.400 /lt</tag>).',
#  '<tag>He</tag> <tag>came</tag> to our OPD with Complete blood <tag>count</tag> which <tag>showed</tag> a <tag>haemoglobin</tag> of <tag>8g/dl</tag>, total <tag>count</tag> <tag>6700/mm3</tag> platelet <tag>count</tag> <tag>24000/mm3</tag> and <tag>ESR</tag> <tag>55mm/hr</tag>.',
#  'Cervical and chest <tag>CT</tag> <tag>revealed</tag> the <tag>presence</tag> of a partially <tag>calcified thyroid mass</tag> slightly plunging in <tag>the anterior mediastinum</tag>.',
#  'A final <tag>diagnosis</tag> of <tag>paratubal borderline serous tumor</tag> was <tag>confirmed</tag>.',
#  'There was no <tag>pain</tag> or other <tag>complaints</tag>.',
#  "<tag>A 65 year-old woman</tag> with <tag>hypertension</tag> and <tag>Parkinson's disease</tag> <tag>presented</tag> with sudden onset severe <tag>chest pain</tag>.",
#  'On <tag>examination</tag> his <tag>vitals</tag> <tag>were-pulse</tag>-<tag>108/minute</tag>, arterial <tag>BP</tag>-<tag>130/80 mm of Hg</tag>, respiratory <tag>rate</tag> of <tag>30 breaths/minute</tag>, <tag>Sp02</tag>-<tag>899%</tag> on room air, <tag>temperature</tag>- <tag>101-degree centigrade</tag>.',
#  'On the other side the infectious process was good <tag>managed</tag> by perfusion of Antibiotics such as Ceftazidim in combination with aminoside.',
#  'A computed tomography <tag>scan</tag> of his <tag>chest</tag> and <tag>abdomen</tag> <tag>revealed</tag> <tag>bilateral lower lobe pneumonia</tag> and two retained Jackson-Pratt <tag>drains</tag> in the <tag>right upper quadrant</tag>.',
#  'All the other routine <tag>investigations</tag> were within <tag>normal limits</tag>.',
#  'At the age of seven years, her serum growth hormone <tag>levels</tag> were <tag>high</tag>, and an insulin-like growth factor 1 generation <tag>test</tag> did not <tag>increase</tag> insulin-like growth factor 1 <tag>levels</tag> (baseline insulin-like growth factor 1 <tag>levels</tag>, <tag>52 μg/L</tag>; reference range, 75 μg/L to 365 μg/L; and peak, <tag>76 μg/L</tag> and <tag>50 μg/L</tag> after <tag>12</tag> and <tag>84 hours</tag>, respectively, from baseline).',
#  'Written informed consent was <tag>obtained</tag> from <tag>the patient</tag> for <tag>using</tag> clinical data and images for <tag>publication</tag> in this study.',
#  'Laboratory workup <tag>showed</tag> an <tag>elevated C-reactive protein</tag> (CRP) of <tag>45.5</tag> with negative <tag>procalcitonin</tag> (<tag>0.04 ng/ml</tag>), white blood <tag>cells</tag> at <tag>12,500</tag> (<tag>PNN</tag> at <tag>9280</tag> and normal <tag>lymphocytes</tag> at <tag>2140</tag>), no <tag>thrombocytopenia</tag>, normal <tag>ferritinemia</tag>, fibrinogen <tag>levels</tag> elevated to <tag>5.37</tag> and negative <tag>D-dimers</tag>.',
#  'On physical <tag>examination</tag>, <tag>the patient</tag> was <tag>awake</tag>, <tag>alert</tag>, <tag>oriented</tag>, and her <tag>blood</tag> <tag>pressure</tag>, <tag>temperature</tag> and <tag>heart</tag> <tag>rate</tag> were within <tag>normal limits</tag>.',
#  '<tag>He</tag> was <tag>returned</tag> to the emergency room after <tag>two days</tag>.',
#  '<tag>She</tag> was <tag>born</tag> from a full-term and uncomplicated <tag>pregnancy</tag> during which <tag>the mother</tag> had no prenatal <tag>ultrasound</tag> (<tag>US</tag>).',
#  'A <tag>chest</tag> X-ray film <tag>disclosed</tag> <tag>bilateral pleural effusion</tag>.',
#  'This <tag>bulk</tag> was easily <tag>reduced</tag> back to <tag>the abdomen</tag> along with <tag>an ipsilateral mobile intravaginal testis</tag>.',
#  '<tag>Histology</tag> of the specimens <tag>showed</tag> a large <tag>B cell lymphoma</tag>.',
#  '<tag>Platelet</tag> <tag>count</tag>, activated partial thromboplastin <tag>time</tag>, <tag>liver</tag> function <tag>tests</tag>, <tag>blood</tag> <tag>urea</tag> <tag>nitrogen</tag>, serum <tag>creatinine</tag>, erythrocyte sediment <tag>rate</tag> and total <tag>cholesterol</tag> were within <tag>normal limits</tag>.',
#  '<tag>Her only child</tag> is a girl <tag>born</tag> vaginally <tag>seven years ago</tag>.',
#  '<tag>Lymphadenopathy</tag> <tag>research</tag> was difficult and <tag>found</tag> no palpable lymph <tag>nodes</tag>.',
#  '<tag>The tumor cells</tag> <tag>showed</tag> nuclear <tag>atypism</tag> and <tag>stratification</tag>, which are histological characteristics of borderline tumor.',
#  'It resulted in disease <tag>progression</tag> according to RECIST with simultaneous <tag>elimination</tag> of sorafenib side effects such as <tag>rash</tag> and <tag>hand-foot syndrome</tag>.',
#  'The <tag>arteriotomy</tag> site was kept <tag>bloodless</tag> with CO2 <tag>insufflation</tag> via an improvised blow-mister.',
#  '<tag>Curettage</tag> and <tag>irrigation</tag> were performed, and <tag>the joint</tag> was <tag>closed</tag> over suction drains.',
#  'Albumin <tag>level</tag> was <tag>3.6 gr/L</tag> with imbalanced electrolyte <tag>levels</tag>.',
#  'Specifically, <tag>she</tag> was <tag>informed</tag> that <tag>surgery</tag> was <tag>necessary</tag> to <tag>correct</tag> the <tag>squint</tag>, irrespective of the <tag>outcome</tag> of the amblyopia therapy.',
#  'No <tag>abnormality</tag> was <tag>found</tag> on abdominal <tag>assessment</tag>.',
#  'The <tag>histology</tag> <tag>showed</tag> that <tag>tumor cells</tag> were arranged in a rare <tag>trabecular pattern</tag> with a prominent lymphoid stroma.',
#  'Nasal Endoscopy <tag>examination</tag> <tag>revealed</tag> a pinnkish burgeoning <tag>mass</tag> <tag>bleeding</tag> on <tag>contact</tag> and <tag>filling</tag> <tag>the right nostril vestibule</tag>.',
#  '<tag>Mr F.B</tag> <tag>a 70-year-old male patient</tag> <tag>presented</tag> in our institution because of the occurrence of a <tag>right epistaxis</tag>.',
#  'The family <tag>history</tag> for <tag>headache</tag> was negative.',
#  'Abdominal <tag>X-ray</tag> <tag>showed</tag> <tag>distension</tag> of an intestinal loop in <tag>the left lumbar region</tag>.',
#  "<tag>He</tag> was <tag>discharged</tag> after <tag>32 days</tag> with output's <tag>weight</tag> <tag>3250g</tag>.",
#  'A histological <tag>review</tag> <tag>confirmed</tag> our diagnosis of <tag>synovial chondromatosis</tag>.',
#  'These symptoms were not <tag>associated</tag> with <tag>vomiting</tag>, <tag>constipation</tag>, <tag>yellow eyes</tag>, <tag>loss</tag> of appetite or <tag>weight loss</tag>.',
#  '<tag>Three years</tag> after <tag>removal</tag> of the lens, <tag>the patient</tag> did not show any <tag>complications</tag>, including <tag>ptosis</tag>.',
#  'Upon taking medical <tag>history</tag> <tag>the patient</tag> <tag>revealed</tag> that was <tag>diagnosed</tag> with <tag>thymoma MG</tag> and on <tag>medication</tag> including <tag>pyridostigmine</tag> bromide 60 mg, <tag>azathioprine</tag> 50 mg and <tag>prednisone</tag> 20 mg.',
#  '<tag>Both eyes</tag> were <tag>double-everted</tag> using lid retractor in order to <tag>assess</tag> the conditions of the <tag>two eyeballs</tag> which were both found to be normal.',
#  '<tag>She</tag> was <tag>started</tag> on <tag>chemotherapy</tag> <tag>one month</tag> after <tag>surgery</tag> and by the time of writing <tag>she</tag> had <tag>received</tag> one cycle of cyclophosphamide, doxorubicin and vincristine.',
#  'Locally diminished actin <tag>coloration</tag> <tag>indicated</tag> <tag>atrophy</tag> of <tag>smooth muscle fibers</tag>.',
#  '<tag>The patient</tag> underwent endoscopic mucosal <tag>resection</tag> using a band ligation <tag>technique</tag> of <tag>an area of nodularity within the Barrett esophagus</tag>.',
#  'Decision for a surgical <tag>intervention</tag> was made and after <tag>informing</tag> <tag>the patient</tag>, <tag>consent</tag> was taken.',
#  'The osmotic <tag>gap</tag> was <tag>45</tag>.',
#  'The rest of the <tag>abdominal organs</tag> and <tag>omentum</tag> looked grossly normal.',
#  'This <tag>confirmed</tag> a co-existent <tag>metastatic breast carcinoma</tag>.',
#  '<tag>She</tag> was <tag>managed</tag> with analgesia, furosemide, spironolactone and lamivudine added for <tag>prevention</tag> of <tag>mother</tag> to <tag>child</tag> trasmission of the hepatitis B infection.',
#  'No capsular of vascular <tag>invasion</tag> was <tag>seen</tag>.',
#  '<tag>Histophotomicrograph</tag> of the excised <tag>breast lesion</tag> <tag>showed</tag> a <tag>2.1 cm</tag> <tag>duct carcinoma</tag>, <tag>positive</tag> for <tag>ER</tag> and <tag>PR</tag> with <tag>1 out of 25 lymph nodes</tag> <tag>positive</tag> for <tag>metastasis</tag>.',
#  '<tag>She</tag> was <tag>treated</tag> with intravenous immunoglobulin resulting in a remarkable <tag>recovery</tag>.',
#  'The macroscopic (gross) <tag>examination</tag> of specimens <tag>revealed</tag> the presence of a <tag>nodule</tag> measuring 1.5 cm in its largest diameter.',
#  '<tag>A haematologist</tag> <tag>consulted</tag> and <tag>peripheral blood film</tag> and <tag>bone marrow</tag> <tag>aspirate</tag> were done.',
#  'A second <tag>biopsy</tag> was performed and the microscopic <tag>features</tag> again <tag>showed</tag> a rich <tag>inflammatory infiltrate</tag> with mononuclear cells and histiocytic cells, characterized by pale <tag>histiocytes</tag> with lobed nuclei, resembling a bean.',
#  '<tag>A 21-year-old male</tag> was <tag>referred</tag> to the gastroenterology clinic for incidental <tag>findings</tag> of severe <tag>chronic pancreatitis</tag> on cross-sectional <tag>imaging</tag> but no associated <tag>symptoms</tag> of <tag>pancreatitis</tag>.',
#  'According to her medical <tag>history</tag>, <tag>she</tag> was <tag>diagnosed</tag> with refractory <tag>ITP</tag> [<tag>platelets</tag> (<tag>PLT</tag>), <tag>3000-8000/μL</tag>] <tag>10 years ago</tag>.',
#  '<tag>Endoscopy</tag> <tag>showed</tag> that <tag>the ampulla</tag> was slightly <tag>enlarged</tag> by a submucosal <tag>tumor</tag>.',
#  '<tag>A 17 months girl</tag> have been <tag>consulted</tag> in our service for <tag>colicky abdominal pain</tag> often associated with <tag>constipation</tag> and <tag>loss</tag> of appetite, since <tag>she</tag> was six months old.',
#  'Her neurological <tag>examination</tag> was <tag>not remarkable</tag> except for her <tag>hemiparesis</tag>.',
#  "This <tag>case</tag> is <tag>unique</tag> in terms of the <tag>patient's</tag> <tag>complication</tag> of severe and medically refractory ITP.",
#  'Her <tag>SLE</tag> was <tag>calm</tag> without any relapse.',
#  'The current <tag>dimensions</tag> of <tag>tumor</tag> was <tag>32x28 cms</tag> with <tag>circumference</tag> of <tag>87 cms</tag>.',
#  '<tag>He</tag> underwent surgical <tag>resection</tag> of this mural <tag>vegetation</tag>.',
#  '<tag>Blood</tag> and surgical material was taken for microbiologic <tag>analysis</tag>.',
#  'However, <tag>the patient</tag> did not <tag>refer</tag> any motor or sensory <tag>deficit</tag>.',
#  'The coombs <tag>test</tag> was <tag>positive</tag>.',
#  'Pelvic <tag>ECT</tag>, <tag>TVS</tag> and tumor <tag>markers</tag> were <tag>checked</tag> every <tag>three months</tag>.',
#  'There was no <tag>lymphadenopathy</tag> and the <tag>nervous system</tag> <tag>examination</tag> was <tag>normal</tag>.',
#  '<tag>The spleen</tag> was not <tag>palpable</tag> but with demonstrable mild <tag>ascites</tag> and bipedal <tag>eodema</tag> up to <tag>the mid shin</tag>.',
#  '<tag>Blood</tag> <tag>pressure</tag> was <tag>100/60mm/hg</tag> and the <tag>heart</tag> <tag>rate</tag> <tag>98 beat/minute</tag>.',
#  'The overall features of the <tag>tumor</tag> were most <tag>consistent</tag> with <tag>metastatic melanoma</tag> occurring in a background of <tag>Barrett esophagus with high-grade dysplasia</tag>.',
#  'In the <tag>immediate postoperative period</tag>, <tag>the patient</tag> developed <tag>hemodynamic collapse</tag> requiring the introduction of <tag>dobutamine</tag>.',
#  'Follow-up <tag>sonogram</tag> obtained <tag>almost 2 months</tag> after the <tag>drainage</tag> <tag>showed</tag> <tag>completely normal liver parenchyma</tag> without <tag>any residual liver cavities</tag>.',
#  'Repeat coronary <tag>angiogram</tag> was done which <tag>showed</tag> that both stents were <tag>patent</tag> and there was no new <tag>coronary lesion</tag>.',
#  '<tag>The tumour</tag> was strongly positive for caldesmon, SMA, desmin, and negative for pancytokeratin and other epithelial, lymphoid and melanocytic markers.',
#  'Clinical <tag>examination</tag> at <tag>the time</tag> was <tag>unrevealing</tag>.',
#  'The <tag>procedure</tag> was post <tag>postponed</tag> until after <tag>she</tag> <tag>delivered</tag> and interval <tag>ultrasounds</tag> were obtained throughout her <tag>pregnancy</tag> to <tag>monitor</tag> the renal <tag>mass</tag>.',
#  '<tag>The liver</tag> was <tag>hard</tag>, <tag>nodular</tag> with irregular edge, mild <tag>tendernes</tag> and had a <tag>bruit</tag> on <tag>auscultation</tag>.',
#  'There was no <tag>facial palsy</tag>.',
#  'Diagnostic <tag>assessment</tag>: the <tag>hemoglobin</tag> was <tag>9.5 g/dl</tag>, the <tag>white blood cell</tag> <tag>count</tag> was <tag>18800/mm 3</tag>, and the C-reactive <tag>protein</tag> (<tag>CRP</tag>) was <tag>75 mm/h</tag>.',
#  'Along with that, a localized <tag>oedema</tag> appeared in <tag>her left upper limb</tag>.',
#  'Social <tag>history</tag> included <tag>smoking</tag> (11 pack-years), family <tag>history</tag> was <tag>non-contributory</tag>.',
#  '<tag>Chest</tag> computed tomography (CT) <tag>scan</tag> <tag>showed</tag> proximal <tag>pulmonary embolism</tag>.',
#  'On the basis of the <tag>failure</tag> of our procedures <tag>an otolaryngologist</tag> performed an <tag>endoscopy</tag> <tag>identifying</tag> <tag>bleeding enlarged vessels</tag>.',
#  'Computed tomography <tag>examination</tag> better <tag>depicted</tag> this congenital <tag>variant</tag> and clearly <tag>showed</tag> the associated <tag>schisis</tag> of <tag>the posterior arch</tag> as well as <tag>unfused spinous process</tag> at the same level on the left side.',
#  'Liver function <tag>tests</tag> <tag>showed</tag> a <tag>high</tag> <tag>ALP</tag> (<tag>1536 U/l</tag>), <tag>elevated</tag> <tag>INR</tag> (<tag>2.15</tag>) though bilirubin, transaminases and serum <tag>proteins</tag> were normal.',
#  '<tag>A fibrous pseudo-capsule</tag> was <tag>noted</tag> around the <tag>tumour</tag> and the <tag>resection</tag> of the tumour appeared <tag>complete</tag>.',
#  'Given his asymptomatic clinical <tag>course</tag>, <tag>he</tag> remains under close <tag>follow-up</tag> without <tag>requiring</tag> any specific <tag>treatment</tag> for <tag>pancreatic insufficiency</tag>.',
#  '<tag>She</tag> was never <tag>hospitalized</tag>, <tag>she</tag> was receiving no <tag>medication</tag> and <tag>she</tag> was doing well one year after <tag>she</tag> <tag>received</tag> a new regimen of <tag>pneumallergens</tag> (Alustal® Stallergenes SA, France).',
#  'His family <tag>history</tag> was <tag>significant</tag> as <tag>his father</tag> had an isolated episode of <tag>pancreatitis</tag> which <tag>required</tag> abdominal <tag>surgery</tag>.',
#  '<tag>Oesogastroduodenoscopy</tag> <tag>showed</tag> <tag>hiatal hernia</tag> without oesophageal varices.',
#  'In mutated SERPINC1 protein a new N-linked glycosylation site is <tag>formed</tag>, however, it is <tag>unclear</tag> if the glycosylation at 219-221 site is possible.',
#  'However <tag>she</tag> <tag>presented</tag> again in <tag>November 2011</tag>, this time with <tag>unstable angina</tag>.',
#  'The renal <tag>ultrasound</tag> <tag>showed</tag> <tag>discretely hyperechoic kidneys cortex</tag> and the absence of renal <tag>malformations</tag>.',
#  'The <tag>review</tag> of systems was essentially <tag>normal</tag> and <tag>she</tag> had enjoyed good <tag>health</tag> since early childhood.',
#  '<tag>A 33-year man</tag> working in Gulf, <tag>presented</tag> with <tag>hemetemesis</tag> <tag>15 days ago in the month of February this year</tag>.',
#  '<tag>The goiter</tag> <tag>measured</tag> <tag>18 x 11 cm</tag>.',
#  'There was a history of significant weight <tag>loss</tag> but no associated early <tag>satiety</tag>, <tag>jaundice</tag>, <tag>fever</tag>, <tag>itch</tag> or spontaneous <tag>bleeding</tag>.',
#  'Histopathological <tag>examination</tag> <tag>confirmed</tag> a <tag>villous adenoma</tag>.',
#  'Energy and protein <tag>intake</tag> was <tag>maintained</tag>, but the ratio of oral <tag>intake</tag> and ONS was <tag>modified</tag> to 70:30.',
#  '<tag>The patient</tag> was on parenteral <tag>nutrition</tag> until <tag>day seven</tag> <tag>postoperatively</tag>.',
#  'Moreover <tag>the ipsilateral scrotum</tag> was <tag>empty</tag> and <tag>the testis</tag> could be <tag>palpated</tag> with difficulty <tag>lying</tag> in a high inguinal position.',
#  '<tag>Both recurrent laryngeal nerves</tag> (<tag>RLN</tag>) were not <tag>identified</tag> because of the <tag>hemorrhage</tag>.',
#  '<tag>She</tag> received 6 cycles of <tag>chemotherapy</tag> with cyclophosphamide, epirubicin, and 5-fluorouracil.',
#  'In <tag>1996</tag>, <tag>deafferentation</tag> of <tag>sacral nerve roots 2, 3 and 4</tag> were carried out bilaterally.',
#  'Laboratory <tag>examination</tag> <tag>showed</tag> <tag>leukocytosis</tag>, <tag>anemia</tag> and <tag>normal</tag> <tag>platelet</tag> <tag>counts</tag>.',
#  "There wasn't any neurovascular <tag>pathology</tag>.",
#  'Clinical <tag>diagnosis</tag> was suggestive of <tag>left paratubal cyst</tag>.',
#  'Magnetic resonance <tag>cholangiopancreatography</tag> (<tag>MRCP</tag>) <tag>showed</tag> severe parenchymal <tag>atrophy</tag> and pancreatic ductal <tag>stones</tag> with ductal dilation to <tag>9mm</tag>.',
#  'Due to his young age and atypical <tag>presentation</tag>, <tag>he</tag> was <tag>referred</tag> for genetic <tag>testing</tag> and <tag>counselling</tag>.',
#  '<tag>The child</tag> has been <tag>discharged</tag> the <tag>next day</tag>.',
#  '<tag>The patient</tag> was <tag>discharged</tag> from the hospital after <tag>20 days</tag> in good health.',
#  'We <tag>received</tag> <tag>a boy 3-year-old boy</tag> with <tag>autistic disorder</tag> on hospital of pediatric ward A at university hospital Mohammed VI of Marrakesh.',
#  '<tag>Ultrasonography</tag> <tag>showed</tag> a <tag>loop</tag> of <tag>herniated small bowel</tag> and <tag>an undescended testis</tag> on the right.',
#  '<tag>Biopsy</tag> of the <tag>ulcerative lesion</tag> was performed and the microscopic features <tag>showed</tag> an <tag>inflammatory infiltrate</tag> rich in <tag>plasma cells</tag>.',
#  'Given the <tag>atypia</tag>, the mitotic <tag>index</tag>, and the Ki67 proliferation <tag>index</tag>, it is a high-grade <tag>large-cell neuroendocrine carcinoma</tag>.',
#  'Laboratory <tag>studies</tag> were remarkable for a HS-troponin <tag>level</tag> <tag>181ng/L</tag>, a <tag>white blood cell</tag> <tag>count</tag> of <tag>14270/mm³</tag> with <tag>48%</tag> <tag>lymphocytes</tag>, and elevated C-reactive <tag>protein</tag> at <tag>90mg/L</tag>.',
#  '<tag>Patient</tag> achieved complete hematological <tag>remission</tag> at <tag>three months</tag> and complete cytogenetic <tag>remission</tag> at <tag>12 months</tag>.',
#  'On <tag>examination</tag>, <tag>patient</tag> was <tag>afebrile</tag> and appeared <tag>pale</tag>.',
#  'The AP <tag>cut</tag> was then proceeded with.',
#  'During <tag>refraction</tag>, her visual <tag>acuity</tag> <tag>improved</tag> to <tag>6/9</tag> and <tag>6/60</tag> in <tag>the right and left eyes</tag> respectively.',
#  'Rectal and vaginal <tag>examination</tag> were <tag>unremarkable</tag>.',
#  'The immunohistochemical <tag>study</tag> of the <tag>tumor</tag> <tag>found</tag> that the <tag>cytokeratin</tag> KL1 and <tag>CK7</tag> and the neuroendocrine <tag>marker</tag> Chromogranin A, <tag>synaptophysin</tag> and <tag>CD56</tag> are <tag>positive</tag>.',
#  'There was <tag>an associated hemivertebra</tag> at the C4 level.',
#  '<tag>A 36-year-old female</tag> showed mild <tag>swelling</tag> in <tag>the right upper eyelid</tag>.',
#  'A plain <tag>radiograph</tag> of the <tag>patient</tag>’s <tag>knees</tag> <tag>revealed</tag> multiple calcific <tag>densities</tag> within <tag>the soft tissues</tag> <tag>surrounding</tag> it on the right one.',
#  'There was no <tag>evidence</tag> of <tag>lung lesions</tag>.',
#  '<tag>He</tag> had developed no <tag>symptoms</tag> during his <tag>hospitalization</tag>.',
#  'At her physical <tag>examination</tag> a facial <tag>nevus</tag> -occurred due to choroid <tag>angioma-on</tag> <tag>the right forehead</tag>, <tag>right eyelid</tag>, <tag>nasal wing</tag> and <tag>the cheek</tag> was <tag>observed</tag>.',
#  'After <tag>8 years</tag> of <tag>treatment</tag>, <tag>the patient</tag> is <tag>free</tag> of <tag>disease</tag>.',
#  'There was <tag>bipedal edema</tag> up to <tag>the mid shin</tag>.',
#  '<tag>The patient</tag> underwent a <tag>surgery</tag> for her enormous <tag>MNG</tag> slightly plunging in <tag>the mediastinum</tag>.',
#  '<tag>She</tag> did not <tag>store</tag> grains at home and had no known <tag>contact</tag> with chemicals or ionizing radiation.',
#  'Abdominal <tag>ultrasound</tag> <tag>showed</tag> <tag>a heterogeneous coarse liver</tag> with multiple hypoechoic <tag>lessions</tag>.',
#  '<tag>Patient</tag> was <tag>sent</tag> to the high dependency unit where <tag>she</tag> <tag>recovered</tag> <tag>postoperatively</tag>.',
#  'The <tag>beginning</tag> of the <tag>symptomatology</tag> goes back to <tag>2 months before</tag> with right nasal <tag>obstruction</tag> of progressive onset, associated with <tag>right epistaxis</tag> and <tag>bloody rhinorrhea</tag> with right chronic <tag>eye watering</tag>.',
#  'The chest <tag>radiograph</tag> <tag>showed</tag> an <tag>enlargement</tag> of the <tag>cardiac silhouette</tag> with a right-sided <tag>pulmonary effusion</tag>.',
#  'But <tag>he</tag> had <tag>reported</tag> having <tag>traveled</tag> by a domestic airline about <tag>twenty days back</tag>.',
#  'On general <tag>examination</tag>, <tag>he</tag> was <tag>dehydrated</tag>, <tag>febrile</tag> and moderately <tag>wasted</tag>.',
#  'On <tag>admission</tag>, <tag>he</tag> was very <tag>pale</tag> with silvery gray scalp hair, white eyelashes, <tag>he</tag> was <tag>hypotonic</tag>, <tag>tachycardic</tag>, <tag>fever</tag> of <tag>40°C</tag>, <tag>lymphoadenopathy</tag> and <tag>hepato-splenomegaly</tag>.',
#  '<tag>She</tag> has never practiced <tag>contraception</tag>.',
#  'At <tag>six months</tag>, <tag>radiographies</tag> <tag>showed</tag> that the <tag>lesion</tag> <tag>healed</tag> completely.',
#  'It is the case of <tag>a 29 years old woman</tag>, G2P1001, <tag>married</tag>, at <tag>9 weeks</tag> of <tag>pregnancy</tag>.',
#  'Before <tag>starting</tag> <tag>corticosteroids</tag>, <tag>we</tag> <tag>analyzed</tag> <tag>electrolytes</tag>.',
#  'After the <tag>operation</tag>, <tag>the patient</tag> underwent functional <tag>rehabilitation</tag> sessions <tag>focusing</tag> on <tag>quadriceps</tag> <tag>strengthening</tag>, with a <tag>daily</tag> exercise <tag>regime</tag> to <tag>supplement</tag> this.',
#  '<tag>Forty year old male</tag> <tag>presented</tag> with a huge <tag>mass</tag> in <tag>this left arm</tag>.',
#  '<tag>The patient</tag> underwent complete endoscopic <tag>removal</tag> of the <tag>tumor</tag> with <tag>ethmoidectomy</tag> and right maxillary <tag>antrostomy</tag>.',
#  'Both <tag>pregnancies</tag> ended <tag>successfully</tag>.',
#  'Recent medical <tag>history</tag> included also endometrial <tag>curettage</tag> for ERPC <tag>a month before</tag> and conservative <tag>therapy</tag> for hemorrhoids <tag>15 days after</tag>.',
#  'After <tag>exposure</tag>, Proximal Tibial, Distal Femoral <tag>Cuts</tag> and <tag>measurement</tag> of extension gaps <tag>the synovium from the anterior Femur</tag> was <tag>removed</tag> and <tag>sizing</tag> was done.',
#  'Multiplanar reconstruction CT <tag>imaging</tag> <tag>revealed</tag> linear fat planes between <tag>the left ovary</tag> and the <tag>cyst</tag>, <tag>indicating</tag> that <tag>the left ovary</tag>, <tag>fallopian tube</tag> and <tag>paratubal cyst</tag> were separate structures, similar to those seen <tag>during surgery</tag>.',
#  'A mediolateral (near vertical) <tag>skin</tag> <tag>incision</tag> was made <tag>originated</tag> from <tag>infra-umbilical level</tag> on <tag>the lateral side of right rectus muscle</tag>.',
#  'A chest <tag>X-ray</tag> was normal while the abdominal <tag>ultrasound</tag> <tag>showed</tag> a <tag>hepatomegaly</tag> and a <tag>splenomegaly</tag>, free biliary <tag>ducts</tag> without <tag>ascites</tag>.',
#  'During <tag>the next 3 days</tag> a second <tag>CT</tag> and an obstetrical <tag>consultation</tag> were conducted with no significant <tag>findings</tag>.',
#  'For <tag>Hypercalcemia</tag>, <tag>patient</tag> has received intravenous <tag>fluid</tag> with furosemide.',
#  '<tag>We</tag> <tag>tried</tag> to <tag>stop</tag> severe <tag>epistaxis</tag> with nasal <tag>packing</tag> and intravenous tranexamic acid.',
#  'Frozen section <tag>pathology</tag> of the removed specimen was <tag>reported</tag> as <tag>benign</tag> (<tag>necrotic tissues</tag>, <tag>teratoma</tag>) and final pathology was mucinous <tag>cystadenoma</tag>.',
#  'Based on this microscopical <tag>finding</tag>, the final <tag>diagnosis</tag> was <tag>periodontal disease</tag> associated with a proliferative non-neoplastic <tag>lesion</tag>.',
#  '<tag>Electrocardiogram</tag> <tag>showed</tag> ischemic <tag>ST-segment elevation</tag> in <tag>inferior and lateral leads</tag>.',
#  '<tag>He</tag> was <tag>diagnosed</tag> with <tag>malignant lymphoma</tag> (<tag>extra-nodal NK/T cell lymphoma nasal type)</tag>, and <tag>chemotherapy</tag> was administered.',
# ...
#  'Late <tag>enhancement</tag> <tag>revealed</tag> a patchy subepicardial <tag>hyperenhancement</tag> of <tag>the medio-distal segments of the anterior and anterolateral walls</tag> which <tag>confirm</tag> the diagnosis of <tag>myocarditis</tag>.',
#  '<tag>The patient</tag> was medically <tag>managed</tag> with Eptifibatide, Aspirin, Clopidogrel and beta blocker since <tag>dissected vessels</tag> were not technically suitable for percutaneous coronary intervention.',
#  'Hyperbaric oxygen <tag>therapy</tag> was not <tag>available</tag> at the setting.',
#  '<tag>The mass</tag> was firm, immobile with an irregular surface not attached to <tag>overlying skin</tag>.',
#  'This was <tag>followed</tag> by <tag>tamoxifen</tag> 20 mg <tag>per day</tag> for <tag>five years</tag>.',
#  "However, on the basis of the <tag>tumor's</tag> radiological <tag>features</tag>, a preliminary diagnosis of <tag>extrahepatic bile duct malignant tumor</tag> was made.",
#  'Proliferation <tag>index</tag> Ki67 is <tag>of the order of 80%</tag>.',
#  '<tag>She</tag> was <tag>commenced</tag> on hypertonic <tag>saline</tag> <tag>4 hourly</tag> and piece of gauze soaked with hypertonic saline was <tag>placed</tag> over the <tag>prolapsed chemosed palpebral conjunctivae</tag> for <tag>3hours</tag> <tag>once in a day</tag>.',
#  'The <tag>LIMA</tag> to <tag>LAD</tag> <tag>anastomosis</tag> was performed with 6-0 prolene suture.',
#  'Serum laboratory <tag>studies</tag>, including <tag>CBC</tag> <tag>count</tag> and inflammatory <tag>markers</tag>, were all <tag>elevated</tag>.',
#  'Its lower end plunges behind the sternal manubrium.',
#  'Histopathological <tag>examination</tag> of the <tag>paratubal cyst</tag> <tag>revealed</tag> the presence of <tag>polypoid lesions</tag> on the <tag>internal surface of the cyst</tag>.',
#  'A CT <tag>Scan</tag> performed <tag>2 years</tag> after <tag>surgery</tag> <tag>showed</tag> no <tag>evidence</tag> of tumour <tag>recurrence</tag>.',
#  'Chest <tag>X-ray</tag> <tag>demonstrated</tag> bilateral <tag>interstitial markings</tag> with a normal cardiac silhouette.',
#  'Cytological <tag>evaluation</tag> of <tag>cerebrospinal fluid</tag> (<tag>CSF</tag>) was also <tag>negative</tag>.',
#  'Meropenem was <tag>administered</tag> for <tag>a total of 2 weeks</tag>.',
#  '<tag>Inspection</tag> under speculum <tag>revealed</tag> <tag>normal gravid external cervical os</tag> and there was no vaginal <tag>discharge</tag>.',
#  "<tag>We</tag> <tag>noticed</tag> a rapidly progressive <tag>amelioration</tag> in her neurological <tag>status</tag> after <tag>finishing</tag> systemic <tag>chemotherapy</tag> and physical <tag>therapy</tag>; however, <tag>the patient's</tag> visual <tag>loss</tag> <tag>showed</tag> no <tag>signs</tag> of <tag>improvement</tag>.",
#  '<tag>Monotherapy</tag> with TKI sorafenib was <tag>prescribed</tag> to <tag>the patient</tag>, which <tag>resulted</tag> in <tag>stabilization</tag> of tumor growth and <tag>elimination</tag> of <tag>pain</tag>.',
#  'Gastrointestinal endoscopic <tag>evaluation</tag> was <tag>unrevealing</tag>.',
#  'Clinical <tag>examination</tag> <tag>showed</tag> a non-pulsatile, painless, axial, irreducible <tag>exophthalmia</tag> with no sign of <tag>conjunctivitis</tag> or <tag>keratitis</tag>, and right <tag>monocular blindness</tag>, <tag>right ptosis</tag>; and fundal <tag>examination</tag> had <tag>objectified</tag> right papillary <tag>oedema</tag>.',
#  'The immunohistochemistry <tag>study</tag> <tag>showed</tag> an expression of the following antibodies Ck (AE1/AE3) on the carcinomatous component, CD3 and CD20 with homogenous distribution in <tag>the stroma</tag>.',
#  '<tag>He</tag> also <tag>complained</tag> of <tag>breathlessness</tag> on exertion and had two <tag>episodes</tag> of <tag>blood in his sputum</tag>.',
#  'A diagnosis of <tag>giant cell tumor</tag> was established.',
#  'Past medical <tag>history</tag> included <tag>Henoch-Schönlein purpura</tag> during childhood.',
#  'A revised diagnosis of <tag>hepatocellular carcinoma on a cirrhotic liver</tag> with decompensation in pregnancy was made.',
#  'Meanwhile irregular spikes of <tag>fever</tag> with <tag>daytime</tag> <tag>variation</tag> accompanied by <tag>night sweats</tag> <tag>persisted</tag>.',
#  '<tag>Normal bilirubin</tag> but <tag>GGT</tag> and <tag>AST</tag> were <tag>raised</tag> (4 times upper limit).',
#  'C3 and C4 complement <tag>fractions</tag> were <tag>low</tag> (<tag>0.2 g/l</tag> and <tag>0.05 g/l</tag>).',
#  'Transthoracic <tag>echocardiography</tag> was <tag>negative</tag> for <tag>vegetations</tag> and <tag>showed</tag> <tag>mild mitral regurgitation</tag>.',
#  'Resuscitation <tag>measures</tag> were taken and an <tag>transfusion</tag> 1120 ml <tag>whole blood</tag>, <tag>red cell pellets</tag> 350 ml and 860 ml <tag>fresh frozen plasma</tag> have <tag>helped</tag> to <tag>management</tag> <tag>coagulopathy</tag> and <tag>anemia</tag>.',
#  'There was no history of <tag>double vision</tag> (<tag>diplopia</tag>) or <tag>pains</tag> on ocular movements.',
#  'This <tag>finding</tag> <tag>shows</tag> <tag>ethmoidal sinus fluid</tag> <tag>retention</tag>.',
#  '<tag>Allogenic stem cell</tag> <tag>transplantation</tag> was not <tag>feasible</tag>.',
#  'The <tag>patient</tag> underwent <tag>surgery</tag>, and the whole <tag>tumor</tag>, from its <tag>base</tag> to the <tag>vertebrae</tag>, was <tag>excised</tag>.',
#  'Immuno-peroxidase <tag>staining</tag> was <tag>positive</tag> for <tag>chromogranin</tag> A.',
#  '<tag>The patient</tag> was <tag>discharged</tag> from the hospital.',
#  '<tag>Mammography</tag> <tag>revealed</tag> a 2.6 cm round hyperdense mass with irregular and speculated margins in <tag>the subareolar area</tag> with associated <tag>microcalcifications</tag> within the mass.',
#  'Her past medical <tag>history</tag> showed a nonsmoking <tag>history</tag> and no significant family <tag>history</tag>.',
#  'Alkaline <tag>phosphatase</tag> (<tag>ALP</tag>) was <tag>normal</tag>.',
#  'Fetal <tag>heart</tag> <tag>rate</tag> was <tag>140 bpm and regular</tag>.',
#  '<tag>The body and tail of the pancreas</tag> including the <tag>tumour</tag> were <tag>resected</tag>.',
#  'No lympho-vascular <tag>component</tag> or intraductal <tag>component</tag> was <tag>noted</tag>.',
#  '<tag>Ultrasonography</tag> <tag>revealed</tag> a heterogenous left ovarian <tag>mass</tag> of <tag>82 millimeters</tag> in diameter, <tag>an empty uterus</tag> and no peritoneal <tag>effusion</tag>.',
#  'After 2 years of age, however, his language <tag>skills</tag> slowly <tag>began</tag> to <tag>regress</tag>.',
#  '<tag>Up to 8 mitoses per 10 HPF</tag> were <tag>counted</tag>.',
#  'The staining <tag>reactions</tag> were <tag>confirmatory</tag> of a <tag>neuroendocrine carcinoma of the pancreas</tag>.',
#  '<tag>The nucleolus</tag> is very large.',
#  '<tag>We</tag> <tag>report</tag> a case of <tag>a male near-term neonate with gestational age of 35 weeks</tag>.',
#  '<tag>She</tag> was <tag>managed</tag> with analgesia, spironolactone and tenofovir <tag>added</tag> for <tag>prevention</tag> of mother-to-child <tag>transmission</tag> of the <tag>hepatitis B infection</tag>.',
#  'Diagnosis of diabetes <tag>decompensation</tag> was made despite absence of <tag>ketone bodies</tag> on urine dipstick <tag>test</tag>.',
#  '<tag>Considering</tag> the mental and nutrition <tag>status</tag> of <tag>the patient</tag>, it was <tag>decided</tag> not to <tag>continue</tag> with the <tag>skin</tag> graft <tag>surgery</tag>.',
#  'His <tag>knees</tag> had become increasingly <tag>swollen</tag>.',
#  '<tag>Two-days</tag> prior the <tag>syncope</tag>, <tag>he</tag> developed <tag>chest pain</tag> and an influenza-like <tag>illness</tag> consisting of <tag>fevers</tag>, <tag>rhinorrhea</tag>, and <tag>sore throat</tag>.',
#  'The remainder of physical <tag>examination</tag> was <tag>unremarkable</tag>.',
#  'The <tag>follow-up</tag> was <tag>4 years</tag>.',
#  'An <tag>MRI</tag> done in <tag>the same period</tag> <tag>shows</tag> a <tag>cure</tag> of <tag>the patient</tag> by a complete disappearance of the <tag>cyst</tag>.',
#  'A <tag>three month</tag> follow up <tag>visit</tag> was <tag>scheduled</tag>, however, <tag>the patient</tag> <tag>defaulted</tag> after the initial <tag>visit</tag>.',
#  'To check for the <tag>COVID-19</tag> <tag>he</tag> was <tag>advised</tag> qualitative polymerase chain reaction (PCR) <tag>test</tag> from the oropharyngeal swab.',
#  'The post-operative pet <tag>scan</tag> <tag>showed</tag> no <tag>distant metastasis</tag>.',
#  'Intraarticular <tag>mass</tag> was <tag>exposed</tag>.',
#  '<tag>A 35-year-old Caucasian woman</tag> known to suffer from late <tag>familial hyperinsulinemic hypoglycemia</tag> due to a well-known <tag>mutation</tag> in <tag>the insulin receptor gene</tag> has been <tag>pregnant</tag> <tag>6 times</tag>.',
#  '<tag>The child</tag> was enrolled in Atanga treatment centre and was being managed with Carbamazepine, multivitamins and Ivermectin.',
#  'The digital rectal <tag>examination</tag> was <tag>unremarkable</tag>.',
#  'Energy and protein were <tag>given</tag> starting from 30 kcal/kg, <tag>increasing</tag> gradually to 50 kcal/kg, and 2 gp/kg divided into oral <tag>nutrition</tag> and oral nutrition <tag>supplements</tag> (<tag>ONS</tag>) with a 50:50 ratio.',
#  'On <tag>9th day</tag> of <tag>illness</tag> <tag>patient</tag> developed painful <tag>neck swelling</tag> accompanied by <tag>fever</tag>, <tag>tremors</tag>, <tag>palpitations</tag>, <tag>hoarseness</tag> of voice and <tag>odynophagia</tag>.',
#  '<tag>He</tag> gave <tag>history</tag> of intake of analgesics for <tag>backache</tag>.',
#  "<tag>A 23-year-old previously healthy man</tag>, <tag>presented</tag> to the hospital's emergency department, with a <tag>3-day</tag> history of <tag>high-grade fever</tag> up to <tag>40°C</tag> and <tag>upper right abdominal pain</tag>.",
#  '<tag>Review</tag> of <tag>this patient</tag> in <tag>January 1999</tag> <tag>revealed</tag> presence of <tag>sinuses</tag> in dorsal <tag>wound</tag> <tag>exuding</tag> purulent <tag>material</tag>.',
#  'Computed <tag>tomography</tag> <tag>showed</tag> <tag>a thyroid nodule of the left lobe</tag> extended to <tag>the isthmus and the right lobe with anterior and posterior capsular rupture</tag> contracting close contact with <tag>the vascular axis left carotid-jugular plunging into the cervicothoracic away from the hole aortic arch</tag>.',
#  'Functional <tag>imaging</tag>, including a positron emission tomography <tag>scan</tag> using 18-fluorodeoxyglucose and gallium-68-DOTA-D-Phe1-Tyr3-octreotide, also failed to <tag>show</tag> increased metabolic <tag>activity</tag> in the <tag>lung</tag> <tag>lesion</tag> or in <tag>her pituitary gland</tag>.',
#  '<tag>Consultation</tag> with <tag>patient neurologist</tag> <tag>regarding</tag> the steroid dose to <tag>reduce</tag> the susceptibility of <tag>developing</tag> adrenal <tag>crisis</tag>.',
#  '<tag>Bisection</tag> of the <tag>tumor</tag> <tag>revealed</tag> that it contained hair and pultaceous material consistent with a <tag>teratoma</tag>, which was later <tag>confirmed</tag> by histopathologic examination.',
#  'After a normal <tag>pre-operative</tag> <tag>work</tag> up, an emergency <tag>laparotomy</tag> was done under general <tag>anesthesia</tag>.',
#  'Based on clinical <tag>examination</tag> and a physical <tag>examination</tag>, <tag>the patient</tag> was <tag>diagnosed</tag> with <tag>secondary amenorrhea</tag>.',
#  '<tag>A 3 years old boy</tag> without any particular diseases <tag>history</tag>, <tag>admitted</tag> to the emergency room for a bipolar <tag>trauma</tag> with a left hemicorporal point of impact following a domestic accident.',
#  'At <tag>one-month</tag> <tag>follow-up</tag> <tag>the patient</tag> made a full <tag>recovery</tag> without any recurring <tag>cardiovascular symptoms</tag> or abnormal electrocardiographic or echocardiographic <tag>findings</tag>.',
#  '<tag>The baby</tag> <tag>died</tag>, after <tag>97 days</tag> of <tag>life</tag>, of septic <tag>shock</tag> and <tag>multiple organ</tag> <tag>failure</tag>.',
#  'A smooth, solid right ovarian <tag>50 an mm-size</tag> <tag>tumour</tag>, as well as small amount of fluid in <tag>the Douglas pouch</tag>, was <tag>found</tag> during the total abdominal <tag>hysterectomy</tag>, bilateral <tag>salpingo-oophorectomy</tag> and staging <tag>biopsy</tag>.',
#  'Magnetic resonance <tag>imaging</tag> (<tag>MRI</tag>) <tag>revealed</tag> a heterogeneous <tag>lesion</tag>.',
#  '<tag>A 3-day-old boy from Kosovo</tag> with <tag>dextro-transposition</tag> of <tag>the great arteries</tag> who developed <tag>progressive heart failure</tag> required an emergency arterial switch <tag>operation</tag>.',
#  '<tag>He</tag> was <tag>referred</tag> to the nearest designated COVID-19 management center, where <tag>he</tag> was <tag>managed</tag> as per national guidelines.',
#  '<tag>The abdomen</tag> was <tag>flat</tag>, and <tag>mobile</tag> with <tag>respiration</tag>.',
#  'Computed tomographic <tag>scan</tag> <tag>showed</tag> massive <tag>ascites</tag>, no <tag>dysmorphic liver</tag>, and a mild <tag>bilateral pleural effusion</tag>.',
#  '<tag>He</tag> was <tag>diagnosed</tag> as having <tag>subacute thyroiditis</tag> and <tag>treated</tag> with oral prednisolone and propranolol.',
#  '<tag>The patient</tag> was <tag>lost</tag> to <tag>follow</tag> up <tag>presenting</tag> <tag>2 years later</tag> and a follow-up CT <tag>scan</tag> <tag>noted</tag> marked <tag>splenic atrophy</tag> with several splenules.',
#  'After two <tag>laparotomies</tag> - both <tag>confirming</tag> <tag>necrotizing enterocolitis</tag> - <tag>the child</tag> <tag>died</tag> <tag>8 days</tag> after <tag>birth</tag>.',
#  'Proteus intelligence <tag>test</tag> in which <tag>she</tag> had <tag>75 points</tag> and accepted as <tag>mildly mentally retarded</tag>.',
#  'After trials of different medication <tag>therapies</tag> without <tag>success</tag>, <tag>she</tag> <tag>started</tag> mirtazapine and her residual <tag>volume</tag> and <tag>aspirations</tag> <tag>decreased</tag> with a dose of 15mg <tag>nightly</tag>.',
#  'The <tag>investigation</tag> <tag>revealed</tag> an elevated <tag>white blood cell</tag> <tag>count</tag> (<tag>WBC</tag>): <tag>545,000/mm³</tag>.',
#  'There was no associated <tag>headache</tag>, <tag>fever</tag>, <tag>vomiting</tag>, joint <tag>pains</tag> or <tag>skin rashes/lesions</tag>.',
#  'Urgent cardiac <tag>catheterization</tag> <tag>revealed</tag> <tag>focal dissections</tag> in <tag>four small caliber coronary arteries in right and left coronary systems</tag> including <tag>right posterior decending, posterolateral, obtuse marginal and septal arteries</tag>.',
#  'On <tag>auscultation</tag>, there was <tag>crepitation</tag> on <tag>the bilateral middle lobes of the lungs</tag>.',
#  'The <tag>tumor</tag> comprised <tag>lymphoid tissue</tag> with numerous <tag>germinal centers with central fibrosis</tag>, <tag>onion-skinning</tag> and rich <tag>interfollicular vascularization</tag>.',
#  'The physical <tag>exam</tag> <tag>revealed</tag> <tag>pallor</tag>, <tag>hepatomegaly</tag>, and grade III <tag>splenomegaly</tag>.',
#  '<tag>Corticosteroids</tag> was <tag>dropped</tag>.',
#  'Nasal <tag>packing</tag> with hemostatic sponge was <tag>successful</tag>, <tag>the pregnant woman</tag> was <tag>admitted</tag> to ob&gyn department.',
#  'There was no <tag>ascites</tag>.',
#  'Thankfully, no surgical <tag>procedure</tag> was required.',
#  'The physical <tag>examination</tag> <tag>showed</tag> only abdominal <tag>distension</tag> related to the important <tag>ascites</tag> without collateral venous <tag>circulation</tag>.',
#  'The oblique paramedian <tag>incision</tag> of <tag>the anterior rectus sheath</tag> was approximately <tag>2cm medial</tag> to <tag>the lateral border of the rectus muscle</tag> and it was <tag>extended</tag> to caudal-lateral direction, down to 1/2cm to <tag>the lateral border of rectus muscle</tag>.',
#  ...]
